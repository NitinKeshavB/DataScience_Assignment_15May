# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df =pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')
df.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
df1.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
"""1. Get the Metadata from the above files."""

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
"""2. Get the row names from the above files."""

df.index.values
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %%
df1.index.values
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
df.columns
# Out:
# Index(['STATION', 'STATION_NAME', 'DATE', 'PRCP', 'SNWD', 'SNOW', 'TMAX',
#        'TMIN', 'WDFG', 'PGTM', 'WSFG', 'WT09', 'WT07', 'WT01', 'WT06', 'WT05',
#        'WT04', 'WT16', 'WT08', 'WT18', 'WT03'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Indicator', 'PUBLISH STATES', 'Year', 'WHO region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %%
"""3. Change the column name from any of the above file."""

df.columns=['STATION_1', 'STATION_NAME_1', 'DATE_1', 'PRCP_1', 'SNWD_1', 'SNOW_1', 'TMAX_1',
       'TMIN_1', 'WDFG_1', 'PGTM_1', 'WSFG_1', 'WT09_1', 'WT07_1', 'WT01_1', 'WT06_1', 'WT05_1',
       'WT04_1', 'WT16_1', 'WT08_1', 'WT18_1', 'WT03_1']

# %%
df.columns
# Out:
# Index(['STATION_1', 'STATION_NAME_1', 'DATE_1', 'PRCP_1', 'SNWD_1', 'SNOW_1',
#        'TMAX_1', 'TMIN_1', 'WDFG_1', 'PGTM_1', 'WSFG_1', 'WT09_1', 'WT07_1',
#        'WT01_1', 'WT06_1', 'WT05_1', 'WT04_1', 'WT16_1', 'WT08_1', 'WT18_1',
#        'WT03_1'],
#       dtype='object')

# %%
"""4. Change the column name from any of the above file and store the changes made
permanently."""
df.columns=['STATION_Changed', 'STATION_NAME_1', 'DATE_1', 'PRCP_1', 'SNWD_1', 'SNOW_1', 'TMAX_1',
       'TMIN_1', 'WDFG_1', 'PGTM_1', 'WSFG_1', 'WT09_1', 'WT07_1', 'WT01_1', 'WT06_1', 'WT05_1',
       'WT04_1', 'WT16_1', 'WT08_1', 'WT18_1', 'WT03_1']
df.columns
# Out:
# Index(['STATION_Changed', 'STATION_NAME_1', 'DATE_1', 'PRCP_1', 'SNWD_1',
#        'SNOW_1', 'TMAX_1', 'TMIN_1', 'WDFG_1', 'PGTM_1', 'WSFG_1', 'WT09_1',
#        'WT07_1', 'WT01_1', 'WT06_1', 'WT05_1', 'WT04_1', 'WT16_1', 'WT08_1',
#        'WT18_1', 'WT03_1'],
#       dtype='object')

# %%
"""5. Change the names of multiple columns."""

df.columns=['STATION_Changed', 'STATION_NAME_changed', 'DATE_changed', 'PRCP_changed', 'SNWD_1', 'SNOW_1', 'TMAX_1',
       'TMIN_1', 'WDFG_1', 'PGTM_1', 'WSFG_1', 'WT09_1', 'WT07_1', 'WT01_1', 'WT06_1', 'WT05_1',
       'WT04_1', 'WT16_1', 'WT08_1', 'WT18_1', 'WT03_1']
df.columns
# Out:
# Index(['STATION_Changed', 'STATION_NAME_changed', 'DATE_changed',
#        'PRCP_changed', 'SNWD_1', 'SNOW_1', 'TMAX_1', 'TMIN_1', 'WDFG_1',
#        'PGTM_1', 'WSFG_1', 'WT09_1', 'WT07_1', 'WT01_1', 'WT06_1', 'WT05_1',
#        'WT04_1', 'WT16_1', 'WT08_1', 'WT18_1', 'WT03_1'],
#       dtype='object')

# %%
"""6. Arrange values of a particular column in ascending order."""

df.sort_values('DATE_changed',ascending = True)
# Out:
#           STATION_Changed STATION_NAME_changed  DATE_changed  PRCP_changed  \
# 22874   GHCND:GM000003319     BERLIN DAHLEM GM      19000101             6
# 59209   GHCND:GM000003342           POTSDAM GM      19000101             4
# 22875   GHCND:GM000003319     BERLIN DAHLEM GM      19000102             2
# 59210   GHCND:GM000003342           POTSDAM GM      19000102            45
# 59211   GHCND:GM000003342           POTSDAM GM      19000103            26
# 22876   GHCND:GM000003319     BERLIN DAHLEM GM      19000103            43
# 22877   GHCND:GM000003319     BERLIN DAHLEM GM      19000104            15
# 59212   GHCND:GM000003342           POTSDAM GM      19000104             0
# 22878   GHCND:GM000003319     BERLIN DAHLEM GM      19000105             0
# 59213   GHCND:GM000003342           POTSDAM GM      19000105             2
# 22879   GHCND:GM000003319     BERLIN DAHLEM GM      19000106             1
# ...

# %%
"""7. Arrange multiple column values in ascending order."""
df.sort_values(["DATE_changed","SNOW_1"],ascending=[True,True])
# Out:
#           STATION_Changed STATION_NAME_changed  DATE_changed  PRCP_changed  \
# 22874   GHCND:GM000003319     BERLIN DAHLEM GM      19000101             6
# 59209   GHCND:GM000003342           POTSDAM GM      19000101             4
# 22875   GHCND:GM000003319     BERLIN DAHLEM GM      19000102             2
# 59210   GHCND:GM000003342           POTSDAM GM      19000102            45
# 22876   GHCND:GM000003319     BERLIN DAHLEM GM      19000103            43
# 59211   GHCND:GM000003342           POTSDAM GM      19000103            26
# 22877   GHCND:GM000003319     BERLIN DAHLEM GM      19000104            15
# 59212   GHCND:GM000003342           POTSDAM GM      19000104             0
# 22878   GHCND:GM000003319     BERLIN DAHLEM GM      19000105             0
# 59213   GHCND:GM000003342           POTSDAM GM      19000105             2
# 22879   GHCND:GM000003319     BERLIN DAHLEM GM      19000106             1
# ...

# %%
"""8. Make DATE_changed as the first column of the dataframe."""

df = df[[ 'DATE_changed','STATION_Changed', 'STATION_NAME_changed',
       'PRCP_changed', 'SNWD_1', 'SNOW_1', 'TMAX_1', 'TMIN_1', 'WDFG_1',
       'PGTM_1', 'WSFG_1', 'WT09_1', 'WT07_1', 'WT01_1', 'WT06_1', 'WT05_1',
       'WT04_1', 'WT16_1', 'WT08_1', 'WT18_1', 'WT03_1']]
df.columns
# Out:
# Index(['DATE_changed', 'STATION_Changed', 'STATION_NAME_changed',
#        'PRCP_changed', 'SNWD_1', 'SNOW_1', 'TMAX_1', 'TMIN_1', 'WDFG_1',
#        'PGTM_1', 'WSFG_1', 'WT09_1', 'WT07_1', 'WT01_1', 'WT06_1', 'WT05_1',
#        'WT04_1', 'WT16_1', 'WT08_1', 'WT18_1', 'WT03_1'],
#       dtype='object')

# %%
"""9. Get the column array using a variable Expected Output:"""

df.STATION_NAME_changed.values
# Out:
# array(['BERLIN TEMPELHOF GM', 'BERLIN TEMPELHOF GM',
#        'BERLIN TEMPELHOF GM', ..., 'SCHONEFELD GM', 'SCHONEFELD GM',
#        'SCHONEFELD GM'], dtype=object)

# %%
"""10. Get the subset rows 11, 24, 37"""
df.iloc[[11,24,37]]
# Out:
#     DATE_changed    STATION_Changed STATION_NAME_changed  PRCP_changed  \
# 11      19310114  GHCND:GME00111445  BERLIN TEMPELHOF GM            15
# 24      19310129  GHCND:GME00111445  BERLIN TEMPELHOF GM            56
# 37      19310212  GHCND:GME00111445  BERLIN TEMPELHOF GM           930
#
#     SNWD_1  SNOW_1  TMAX_1  TMIN_1  WDFG_1  PGTM_1   ...    WT09_1  WT07_1  \
# 11   -9999   -9999       0     -22   -9999   -9999   ...     -9999   -9999
# 24   -9999   -9999      11     -11   -9999   -9999   ...     -9999   -9999
# 37   -9999   -9999      61   -9999   -9999   -9999   ...     -9999   -9999
#
#     WT01_1  WT06_1  WT05_1  WT04_1  WT16_1  WT08_1  WT18_1  WT03_1
# 11   -9999   -9999   -9999   -9999   -9999   -9999   -9999   -9999
# 24   -9999   -9999   -9999   -9999   -9999   -9999   -9999   -9999
# 37   -9999   -9999   -9999   -9999   -9999   -9999   -9999   -9999
#
# [3 rows x 21 columns]

# %%
"""11. Get the subset rows excluding 5, 12, 23, and 56"""

exclude_df = df.index.isin([5,12,23,56])
df[~exclude_df]
# Out:
#         DATE_changed    STATION_Changed STATION_NAME_changed  PRCP_changed  \
# 0           19310101  GHCND:GME00111445  BERLIN TEMPELHOF GM            46
# 1           19310102  GHCND:GME00111445  BERLIN TEMPELHOF GM           107
# 2           19310103  GHCND:GME00111445  BERLIN TEMPELHOF GM         -9999
# 3           19310105  GHCND:GME00111445  BERLIN TEMPELHOF GM            13
# 4           19310106  GHCND:GME00111445  BERLIN TEMPELHOF GM         -9999
# 6           19310108  GHCND:GME00111445  BERLIN TEMPELHOF GM            13
# 7           19310109  GHCND:GME00111445  BERLIN TEMPELHOF GM            10
# 8           19310110  GHCND:GME00111445  BERLIN TEMPELHOF GM         -9999
# 9           19310112  GHCND:GME00111445  BERLIN TEMPELHOF GM         -9999
# 10          19310113  GHCND:GME00111445  BERLIN TEMPELHOF GM            13
# 11          19310114  GHCND:GME00111445  BERLIN TEMPELHOF GM            15
# ...

# %%
users =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
sessions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv' )
products =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv' )
transactions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
users
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
transactions.head(10)
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4

# %%
"""12. Join users to transactions, keeping all rows from transactions and only matching
rows from users (left join)"""

pd.merge(transactions,users, how='left', on = "UserID")
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# ...

# %%
"""13. Which transactions have a UserID not in users?"""
notinusers=pd.merge(transactions,users, how='left', on = "UserID")
notinusers[notinusers['User'].isnull()][['UserID']]
# Out:
#    UserID
# 0     7.0
# 7     NaN
# 8     7.0

# %%
"""14) Join users to transactions, keeping only rows from transactions and users that
match via UserID (inner join)"""

pd.merge(transactions,users, how='inner', on = "UserID")
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %%
"""15) Join users to transactions, displaying all matching rows AND all non-matching rows
(full outer join)"""
pd.merge(transactions,users, how='outer', on = "UserID")
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaN     4.0        NaN       NaN   Brielle
# 11            NaN             NaN     5.0        NaN       NaN  Benjamin
#
# ...

# %%
"""16) Determine which sessions occurred on the same day each user registered"""

#sessions.head()
#users.head()

AllUserSession=pd.merge(users,sessions, how='inner', on = ["UserID"])
AllUserSession[AllUserSession["Registered"] == AllUserSession["SessionDate"]]
# Out:
#    UserID     User  Gender  Registered   Cancelled  SessionID SessionDate
# 1       2    Pedro    male  2010-08-01  2010-08-08          2  2010-08-01
# 7       4  Brielle  female  2013-07-17         NaN          9  2013-07-17

# %%
"""17) Build a dataset with every possible (UserID, ProductID) pair (cross join)"""

users['CrossId'] = 1
products['CrossId'] = 1

crossjoin=pd.merge(users,products, how='inner', on = ["CrossId"])
crossjoin[['UserID','ProductID']]
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %%
"""18) Determine how much quantity of each product was purchased by each user"""

userproducts=pd.merge(users,products, how='inner', on = ["CrossId"])
TotalTransactions=pd.merge(userproducts,transactions, how='left', on = ["UserID","ProductID"])
TotalTransactions[["UserID","ProductID","Quantity"]].fillna(0,axis=1)
# Out:
#     UserID  ProductID  Quantity
# 0        1          1       0.0
# 1        1          2       3.0
# 2        1          3       0.0
# 3        1          4       0.0
# 4        1          5       0.0
# 5        2          1       0.0
# 6        2          2       0.0
# 7        2          3       0.0
# 8        2          4       1.0
# 9        2          5       6.0
# 10       3          1       0.0
# 11       3          2       0.0
# 12       3          3       1.0
# 13       3          4       1.0
# 14       3          4       1.0
# 15       3          4       4.0
# 16       3          5       0.0
# 17       4          1       0.0
# 18       4          2       0.0
# 19       4          3       0.0
# 20       4          4       0.0
# 21       4          5       0.0
# 22       5          1       0.0
# 23       5          2       0.0
# 24       5          3       0.0
# 25       5          4       0.0
# 26       5          5       0.0

# %%
"""19) For each user, get each possible pair of pair transactions (TransactionID1,
TransacationID2)"""
transactions
users

pd.merge(transactions,transactions, how='left', on = ["UserID"])
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 2        2011-05-26     3.0            4           1
# 3                 2        2011-05-26     3.0            4           1
# 4                 2        2011-05-26     3.0            4           1
# 5                 2        2011-05-26     3.0            4           1
# 6                 3        2011-06-16     3.0            3           1
# 7                 3        2011-06-16     3.0            3           1
# 8                 3        2011-06-16     3.0            3           1
# 9                 3        2011-06-16     3.0            3           1
# 10                4        2012-08-26     1.0            2           3
# 11                5        2013-06-06     2.0            4           1
# ...

# %%
"""20) Join each user to his/her first occuring transaction in the transactions table"""







mintransactions=transactions.groupby('UserID')[['TransactionDate']].min()

mintransactionssub=pd.merge(transactions,mintransactions, how='inner', on = ["UserID","TransactionDate"])

final=pd.merge(users,mintransactionssub, how='left', on = ["UserID"])
final
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN            4.0
# 1       2     Pedro    male  2010-08-01  2010-08-08            5.0
# 2       3  Caroline  female  2012-10-23  2016-06-07            2.0
# 3       4   Brielle  female  2013-07-17         NaN            NaN
# 4       5  Benjamin    male  2010-11-25         NaN            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2011-05-26        4.0       1.0
# 3             NaN        NaN       NaN
# 4             NaN        NaN       NaN

# %%
"""21) Test to see if we can drop columns"""
final.columns
# Out:
# Index(['UserID', 'User', 'Gender', 'Registered', 'Cancelled', 'TransactionID',
#        'TransactionDate', 'ProductID', 'Quantity'],
#       dtype='object')

# %%
## dropped few columns

list(final.dropna(thresh=int(final.shape[0] * .9), axis=1).columns)
# Out:
# ['UserID', 'User', 'Gender', 'Registered']

# %%
missing_info=list(final.columns[final.isnull().any()]) 
missing_info
# Out:
# ['Cancelled', 'TransactionID', 'TransactionDate', 'ProductID', 'Quantity']

# %%
for col in missing_info:
    num_missing = final[final[col].isnull() == True].shape[0] 
    print('number missing for column {}: {}'.format(col, num_missing))
# Out:
# number missing for column Cancelled: 3
# number missing for column TransactionID: 2
# number missing for column TransactionDate: 2
# number missing for column ProductID: 2
# number missing for column Quantity: 2

# %%
for col in missing_info:
    percent_missing = final[final[col].isnull() == True].shape[0]/final.shape[0]
    print('percent missing for column {}: {}'.format( col,percent_missing))
# Out:
# percent missing for column Cancelled: 0.6
# percent missing for column TransactionID: 0.4
# percent missing for column TransactionDate: 0.4
# percent missing for column ProductID: 0.4
# percent missing for column Quantity: 0.4
